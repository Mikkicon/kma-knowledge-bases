# %%
# %pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (8.1.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipywidgets) (0.1.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipywidgets) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: backcall in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: appnope in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /Users/mp/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import ipywidgets as widgets
import importlib  
try:
  constants = importlib.import_module("knowledge-bases.hw1.constants")
except:
  print('')
from constants import get_output_paths, OUTPUT_FILE_NAME

# %%
df.dtypes
# Out:
# URL             object
# Company         object
# Job             object
# Salary          object
# Location        object
# Views            int64
# Responses      float64
# Category        object
# Employment      object
# Experience      object
# English         object
# Domain          object
# Description     object
# dtype: object

# %%
df = pd.read_csv(get_output_paths(OUTPUT_FILE_NAME)[0])

def extract_from_salary(salary_range):
    if pd.isna(salary_range):
        return None
    if "до" in salary_range:
        return None
    salary_parts = salary_range.split('-')
    return int(salary_parts[0])

def extract_to_salary(salary_range):
    if pd.isna(salary_range):
        return None
    if "до" in salary_range:
        return salary_range.split()[1]
    salary_parts = salary_range.split('-')
    if len(salary_parts) == 1:
        return None
    salary_to = int(salary_parts[1])
    return salary_to

def extract_countries(location):
    return ",".join(location.split("(")[0].replace(" ", "").split(','))

def extract_cities(location):
    countries_cities = location.split("(")
    if len(countries_cities) == 1:
        return None
    return ",".join(countries_cities[1].replace(" ", "").replace(")", "").split(','))

def extract_english(english):
    if pd.isna(english):
        return None
    return english.replace("Англійська:", "").replace(" ", "")

df['Salary_from'] = df['Salary'].apply(extract_from_salary)
df['Salary_to'] = df['Salary'].apply(extract_to_salary)
df['Countries'] = df['Location'].apply(extract_countries)
df['Cities'] = df['Location'].apply(extract_cities)
df['English'] = df['English'].apply(extract_english)
df['Salary_from'] = pd.to_numeric(df['Salary_from'], errors='coerce')
df['Salary_to'] = pd.to_numeric(df['Salary_to'], errors='coerce')

df[~df['Salary'].isna()].head(5)
# Out:
#                                                   URL        Company  \
# 6      https://djinni.co/jobs/606318-storage-inzhener   Object First
# 7       https://djinni.co/jobs/597673-finance-analyst       First.ua
# 19  https://djinni.co/jobs/606308-middle-senior-cl...         itsoft
# 21  https://djinni.co/jobs/598576-head-of-digital-...        Supplax
# 27  https://djinni.co/jobs/606304-trainee-affiliat...  Infinite Plus
#
#                                           Job     Salary  \
# 6                             Storage інженер  1200-2000
# 7                             Finance Analyst  2000-3000
# 19  Middle/Senior Cloud Operations Specialist  4000-6000
# 21                  Head of digital marketing  1200-1700
# 27                  Trainee Affiliate Manager    300-500
#
#                               Location  Views  Responses   Category  \
# 6                       Україна (Київ)     12        1.0   Sysadmin
# 7                       Україна (Київ)      7        NaN      Other
# 19  Вірменія,     Ізраїль,     Україна     20        3.0     DevOps
# 21                             Україна      5        1.0  Marketing
# 27                             Україна     25        3.0  Marketing
#
#           Employment  Experience             English  \
# 6   Тільки віддалено         3.0                None
# 7        Тільки офіс         2.0                None
# 19  Тільки віддалено         3.0  Upper-Intermediate
# 21  Тільки віддалено         2.0        Intermediate
# 27  Тільки віддалено         NaN  Upper-Intermediate
#
#                              Domain  \
# 6                   Домен: Security
# 7                   Домен: Gambling
# 19            Домен: Hardware / IoT
# 21   Домен: Advertising / Marketing
# 27  Домен: E-commerce / Marketplace
#
#                                           Description  Salary_from  Salary_to  \
# 6   Обов’язки:Виконання різноманітних видів ручног...       1200.0     2000.0
# 7   Шукаємо:-Має 2+ роки досвіду на позиції Financ...       2000.0     3000.0
# 19  General informationCommit is the leading syste...       4000.0     6000.0
# 21  Хто ми?Ми працюємо по моделі Убер. Займаємося ...       1200.0     1700.0
# 27  We are looking for Trainee Affiliate Manager t...        300.0      500.0
#
#                    Countries Cities
# 6                    Україна   Київ
# 7                    Україна   Київ
# 19  Вірменія,Ізраїль,Україна   None
# 21                   Україна   None
# 27                   Україна   None

# %%
from ipywidgets import Box, VBox, widgets
import math

category_dropdown = widgets.Dropdown( options=list(set(df['Category'].values)), description='Category:')
experience_dropdown = widgets.Dropdown( options=[x for x in list(set(df['Experience'].values)) if not math.isnan(x)], description='Experience:')
country_dropdown = widgets.Dropdown( options=list(set([y.strip() for x in list(set(df['Countries'].values)) for y in x.split(',')])), value= "Україна", description='Country:')

multi_cities = [x for x in list(set(df['Cities'].values)) if not(type(x) == float and math.isnan(x))]
city_dropdown = widgets.Dropdown( options=list(set([y.strip() for x in multi_cities if x for y in x.split(',') if '+' not in y.strip()])), description='City:')
english_dropdown = widgets.Dropdown( options=list(set(df['English'].values)), description='English:')
employment_dropdown = widgets.Dropdown( options=list(set([x for x in df['Employment'].values if ',' not in x])), description='Employment:')

multi_domains = [x.replace("Домен: ", "") for x in list(set(df['Domain'].values)) if not(type(x) == float and math.isnan(x))]
domains_multiselect = widgets.SelectMultiple(
    options=[y.strip() for x in multi_domains for y in x.split('/')],
    description='Not interested in Domains:',
)

salary_from_slider = widgets.IntSlider(
  value=1000,
    min=0,
    max=max([x for x in df['Salary_to'].values if not math.isnan(x)]),
    step=500,
    description='Salary from:',
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
widget_list = [
  category_dropdown, 
  experience_dropdown, 
  salary_from_slider, 
  country_dropdown,
  city_dropdown, 
  english_dropdown, 
  employment_dropdown, 
  domains_multiselect
  ]

changed_idxs = set()
for widget in widget_list:
  widget.observe(lambda change: changed_idxs.add(widget_list.index(change.owner)), names='value')

Box([VBox(children=widget_list)])
# Out:
# Box(children=(VBox(children=(Dropdown(description='Category:', options=('Lead', 'Rust', 'Data Analyst', 'Sales…

# %%
# Посада                    -> Job
job = "Data"
# Категорія                 -> Category
category = category_dropdown.value
# Навички                   -> FULL_TEXT in Description
skills = ["python"]
# Досвід роботи             -> Experience
experience = experience_dropdown.value
# Зарплатні очікування      -> Salary [estimate]
salary_from = salary_from_slider.value 
# Країна перебування        -> Location
country = country_dropdown.value
# Місто перебування         -> Location
city = city_dropdown.value
# Рівень англійської        -> English
english = english_dropdown.value
# Варіанти зайнятості       -> Employment
employment = employment_dropdown.value
# Не розглядаю              -> Domain
domains = domains_multiselect.value

(job,category,skills,experience,salary_from,country,city,english,employment,domains, changed_idxs)
# Out:
# ('Data',
#  'Lead',
#  ['python'],
#  1.0,
#  1000,
#  'Україна',
#  'Львів',
#  'Upper-Intermediate',
#  'Тільки віддалено',
#  (),
#  set())

# %%
Job_bool =   (df['Job'].str.contains(job, case=False, na=False) if job else True) 
Category_bool =   (df['Category'].str.lower() == category.lower() if 0 in changed_idxs else True) 
Description_bool =   (df['Description'].str.contains('|'.join(skills), case=False, na=False) if len(skills) else True) 
Experience_bool =   (df['Experience'] <= experience if 1 in changed_idxs else True) 
Salary_bool =   (df['Salary'].isna() | ((df['Salary_from'] <= salary_from) & (df['Salary_to'] >= salary_from)) if 2 in changed_idxs else True) 
Countries_bool =   (df['Countries'].str.contains(country, case=False, na=False) if 3 in changed_idxs else True) 
Cities_bool =   (df['Cities'].str.contains(city, case=False, na=False) if 4 in changed_idxs else True) 
English_bool =   (df['English'].isna() | (df['English'] == english) if 5 in changed_idxs else True) 
Employment_bool =   (df['Employment'].str.contains(employment, case=False, na=False) if 6 in changed_idxs else True) 
Domain_bool =  (~df['Domain'].str.contains('|'.join(domains), case=False, na=False) if 7 in changed_idxs else True)

# %%
(
  0 if type(Job_bool) == bool else (Job_bool==True).sum(),
  0 if type(Category_bool) == bool else (Category_bool==True).sum(),
  0 if type(Description_bool) == bool else (Description_bool==True).sum(),
  0 if type(Experience_bool) == bool else (Experience_bool==True).sum(),
  0 if type(Salary_bool) == bool else (Salary_bool==True).sum(),
  0 if type(Countries_bool) == bool else (Countries_bool==True).sum(),
  0 if type(Cities_bool) == bool else (Cities_bool==True).sum(),
  0 if type(English_bool) == bool else (English_bool==True).sum(),
  0 if type(Employment_bool) == bool else (Employment_bool==True).sum(),
  0 if type(Domain_bool) == bool else (Domain_bool==True).sum(),
)
# Out:
# (36, 0, 153, 0, 0, 0, 0, 0, 0, 0)

# %%
df[
  Job_bool &
  Category_bool &
  Description_bool &
  Experience_bool &
  Salary_bool &
  Countries_bool &
  Cities_bool &
  English_bool &
  Employment_bool &
  Domain_bool
  ]
# Out:
#                                                    URL  \
# 9    https://djinni.co/jobs/598678-junior-middle-da...
# 73          https://djinni.co/jobs/606275-data-analyst
# 76   https://djinni.co/jobs/580922-middle-data-engi...
# 163  https://djinni.co/jobs/606196-data-scientist-r...
# 169       https://djinni.co/jobs/606193-data-scientist
# 217    https://djinni.co/jobs/606153-lead-data-analyst
# 218  https://djinni.co/jobs/606159-middle-data-engi...
# 349  https://djinni.co/jobs/606020-data-quality-ass...
# 356  https://djinni.co/jobs/606015-middle-big-data-...
# 401  https://djinni.co/jobs/605997-senior-data-scie...
# 487  https://djinni.co/jobs/581792-data-engineer-he...
# 506  https://djinni.co/jobs/605920-azure-data-engin...
# 531  https://djinni.co/jobs/605506-senior-data-analyst
# 548  https://djinni.co/jobs/605889-middle-data-scie...
# 647         https://djinni.co/jobs/597771-data-analyst
# 677             https://djinni.co/jobs/605777-database
# 749  https://djinni.co/jobs/605706-gcp-data-enginee...
# 770        https://djinni.co/jobs/605688-data-engineer
# 839  https://djinni.co/jobs/605626-senior-data-engi...
# 866  https://djinni.co/jobs/605599-senior-data-analyst
# 942  https://djinni.co/jobs/568694-data-architect-aws-
# 987  https://djinni.co/jobs/605484-senior-data-auto...
#
#                          Company  \
# 9                       BetterMe
# 73                     12go.asia
# 76                Sigma Software
# 163                Grid Dynamics
# 169                       AMLBot
# 217                       dok.ua
# 218                     GR8 Tech
# 349  Dash Financial Technologies
# 356                      Adjutor
# 401                 Eastern Peak
# 487               Sigma Software
# 506                       Luxoft
# 531                  SEOBROTHERS
# 548                          EVO
# 647                       MAUDAU
# 677         SoloWay Technologies
# 749                     ITExpert
# 770            TrueAutomation.io
# 839                      Upstaff
# 866          TemaBit Fozzy Group
# 942          TemaBit Fozzy Group
# 987                        JOIDY
#
#                                                  Job     Salary  \
# 9                         Junior/Middle Data Analyst        NaN
# 73                                      Data Analyst  2500-3000
# 76          Middle Data Engineer (Healthcare domain)        NaN
# 163          Data Scientist (Retraining Opportunity)        NaN
# 169                                   Data Scientist        NaN
# 217                                Lead Data Analyst        NaN
# 218        Middle Data Engineer for Data Models Team        NaN
# 349                  Data Quality Assurance Engineer  5000-5500
# 356                         Middle Big Data Engineer    до 5600
# 401  Senior Data Science / Machine Learning Engineer        NaN
# 487                Data Engineer (Healthcare domain)        NaN
# 506                     Azure Data Engineer, Wroclaw        NaN
# 531                              Senior Data Analyst        NaN
# 548                            Middle Data Scientist        NaN
# 647                                     Data Analyst        NaN
# 677                                         Database        NaN
# 749  GCP Data Engineer для створення продукту з нуля        NaN
# 770                                    Data Engineer  1500-2500
# 839                             Senior Data Engineer        NaN
# 866                              Senior Data Analyst        NaN
# 942                             Data Architect (AWS)        NaN
# 987                  Senior Data Automation Engineer        NaN
#
#                                               Location  Views  Responses  \
# 9                                       Україна (Київ)     20        3.0
# 73                                      Україна (Київ)     81       23.0
# 76   Болгарія,     Чехія,     Угорщина,     Польща,...      6        1.0
# 163              Україна (Дніпро, Київ, Львів, Харків)     42        2.0
# 169                                     Україна (Київ)     44        7.0
# 217                                     Україна (Київ)     14        1.0
# 218                     Чехія,     Польща,     Україна     67        3.0
# 349                                    Сполучені Штати    157       24.0
# 356                                            Україна     56       10.0
# 401          Україна,     Ізраїль,     Велика Британія     40       11.0
# 487  Болгарія,     Польща,     Португалія,     Руму...     54        6.0
# 506                                             Польща      8        1.0
# 531                                               Кіпр     51       13.0
# 548                                     Україна (Київ)     44        6.0
# 647                                     Україна (Київ)     58        7.0
# 677                                            Україна     25        2.0
# 749                                     Україна (Київ)     25        3.0
# 770                                            Україна     35        2.0
# 839                                            Україна     40        3.0
# 866                                            Україна     46        4.0
# 942                                     Україна (Київ)     40        1.0
# 987                                            Україна    115       16.0
#
#           Category         Employment  Experience             English  \
# 9     Data Analyst  Office або Remote         1.0                None
# 73    Data Analyst   Тільки віддалено         3.0        Intermediate
# 76   Data Engineer  Office або Remote         2.0  Upper-Intermediate
# 163   Data Science  Office або Remote         3.0  Upper-Intermediate
# 169   Data Science  Office або Remote         3.0        Intermediate
# 217   Data Analyst    Гібридна робота         3.0        Intermediate
# 218  Data Engineer  Office або Remote         2.0  Upper-Intermediate
# 349  QA Automation   Тільки віддалено         5.0  Upper-Intermediate
# 356  Data Engineer   Тільки віддалено         3.0  Upper-Intermediate
# 401   Data Science   Тільки віддалено         5.0  Upper-Intermediate
# 487   Data Science  Office або Remote         3.0  Upper-Intermediate
# 506  Data Engineer  Office або Remote         5.0  Upper-Intermediate
# 531   Data Analyst        Тільки офіс         3.0  Upper-Intermediate
# 548   Data Science    Гібридна робота         3.0                None
# 647   Data Analyst  Office або Remote         3.0                None
# 677            SQL   Тільки віддалено         5.0  Upper-Intermediate
# 749  Data Engineer        Тільки офіс         3.0                None
# 770  Data Engineer   Тільки віддалено         3.0  Upper-Intermediate
# 839  Data Engineer   Тільки віддалено         3.0  Upper-Intermediate
# 866   Data Analyst  Office або Remote         3.0                None
# 942         DevOps  Office або Remote         3.0  Upper-Intermediate
# 987  QA Automation   Тільки віддалено         5.0  Upper-Intermediate
#
#                                  Domain  \
# 9           Домен: Healthcare / MedTech
# 73              Домен: Travel / Tourism
# 76          Домен: Healthcare / MedTech
# 163                                 NaN
# 169          Домен: Blockchain / Crypto
# 217     Домен: E-commerce / Marketplace
# 218                     Домен: Gambling
# 349                      Домен: Fintech
# 356  Домен: Machine Learning / Big Data
# 401                                 NaN
# 487         Домен: Healthcare / MedTech
# 506                                 NaN
# 531                     Домен: Gambling
# 548     Домен: E-commerce / Marketplace
# 647     Домен: E-commerce / Marketplace
# 677                                 NaN
# 749          Домен: Blockchain / Crypto
# 770                         Домен: SaaS
# 839                                 NaN
# 866     Домен: E-commerce / Marketplace
# 942     Домен: E-commerce / Marketplace
# 987             Домен: Travel / Tourism
#
#                                            Description  Salary_from  \
# 9    ABOUT US:BetterMe is a health & wellness platf...          NaN
# 73   About 12Go.Asia: - Leading multi-modal OTA (On...       2500.0
# 76   Sigma Software is looking for a motivated Data...          NaN
# 163  We have a unique retraining opportunity for in...          NaN
# 169  AMLBot is looking for an experienced Data Scie...          NaN
# 217  🔊 dok.ua - працюємо як e-commerce з 10-річним ...          NaN
# 218  About your key responsibilities and impact:- W...          NaN
# 349  Please make sure you have read the Job Descrip...       5000.0
# 356  Our partner is a one-stop custom software deve...          NaN
# 401  We are looking for an experienced Data Science...          NaN
# 487  Sigma Software шукає вмотивованого Data-інжене...          NaN
# 506  Project DescriptionYou will be working in a gl...          NaN
# 531  We are looking for an experienced Senior Data ...          NaN
# 548  Prom.ua – найбільший маркетплейс України, де п...          NaN
# 647  Опис• Моніторинг і аналіз продажів, включаючи ...          NaN
# 677  Part time participation: consultation at START...          NaN
# 749  Компанія закритого типу, що спеціалізується на...          NaN
# 770  Data Engineer is responsible for data extracti...       1500.0
# 839  Summary- 3+ years of expertise in data enginee...          NaN
# 866  Привіт!Ми — E-Com — команда закоханих у Foodte...          NaN
# 942  Привіт!Ми - TemaBit Fozzy Group — команда фана...          NaN
# 987  JOIDY is looking for a Senior Data Automation ...          NaN
#
#      Salary_to                                   Countries  \
# 9          NaN                                     Україна
# 73      3000.0                                     Україна
# 76         NaN   Болгарія,Чехія,Угорщина,Польща,Португалія
# 163        NaN                                     Україна
# 169        NaN                                     Україна
# 217        NaN                                     Україна
# 218        NaN                        Чехія,Польща,Україна
# 349     5500.0                              СполученіШтати
# 356     5600.0                                     Україна
# 401        NaN              Україна,Ізраїль,ВеликаБританія
# 487        NaN  Болгарія,Польща,Португалія,Румунія,Україна
# 506        NaN                                      Польща
# 531        NaN                                        Кіпр
# 548        NaN                                     Україна
# 647        NaN                                     Україна
# 677        NaN                                     Україна
# 749        NaN                                     Україна
# 770     2500.0                                     Україна
# 839        NaN                                     Україна
# 866        NaN                                     Україна
# 942        NaN                                     Україна
# 987        NaN                                     Україна
#
#                               Cities
# 9                               Київ
# 73                              Київ
# 76                              None
# 163         Дніпро,Київ,Львів,Харків
# 169                             Київ
# 217                             Київ
# 218                             None
# 349                             None
# 356                             None
# 401                             None
# 487  Вінниця,Дніпро,Житомир+ще10міст
# 506                             None
# 531                             None
# 548                             Київ
# 647                             Київ
# 677                             None
# 749                             Київ
# 770                             None
# 839                             None
# 866                             None
# 942                             Київ
# 987                             None
